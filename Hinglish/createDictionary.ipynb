# %%
import pickle

# %%
transliterate = {}
with open("Data/hindi_english_transliteration.txt", encoding="utf8") as f:
    for line in f:
       (key, val) = line.split()
       transliterate[key] = val

# %%
with open("Data/crowd-indic-transliteration-data-master/crowd_transliterations.hi-en.txt", encoding="utf8") as f:
    for line in f:
       (key, val) = line.split()
       transliterate[key] = val

# %%
for i in range(1, 19):
    filename = "Data/Hindi - Word transliteration pairs 2/Chat/" "user-" + str(i) + ".txt"
    file = open(filename, "r", encoding="utf8")
    english_sentence = file.readline()
    while (english_sentence != ''):
        english_sentence = file.readline()
        if (english_sentence=='\r\n'):
            english_sentence = file.readline()
        hindi_sentence = file.readline()
        english_words = english_sentence.split(';')
        hindi_words = hindi_sentence.split(';')
        for eword, hword in zip(english_words, hindi_words):
            transliterate[eword] = hword

# %%
for i in range(1, 19):
    filename = "Data/Hindi - Word transliteration pairs 2/Scenario/" "user-" + str(i) + ".txt"
    file = open(filename, "r", encoding="utf8")
    english_sentence = file.readline()
    while (english_sentence != ''):
        english_sentence = file.readline()
        if (english_sentence=='\r\n'):
            english_sentence = file.readline()
        hindi_sentence = file.readline()
        english_words = english_sentence.split(';')
        hindi_words = hindi_sentence.split(';')
        for eword, hword in zip(english_words, hindi_words):
            transliterate[eword] = hword

# %%
for i in range(1, 19):
    filename = "Data/Hindi - Word transliteration pairs 2/Dictation Experiment/" "user-" + str(i) + ".txt"
    file = open(filename, "r", encoding="utf8")
    english_sentence = file.readline()
    while (english_sentence != ''):
        english_sentence = file.readline()
        if (english_sentence=='\r\n'):
            english_sentence = file.readline()
        hindi_sentence = file.readline()
        english_words = english_sentence.split(';')
        hindi_words = hindi_sentence.split(';')
        for eword, hword in zip(english_words, hindi_words):
            transliterate[eword] = hword

# %%
hindi2eng = {}

with open("Data/UW_Hindi_Dict_20131003/UW-Hindi_Dict-20131003.txt",encoding="utf8") as f:
    for line in f:
        #print line.partition('[')[-1].rpartition(']')[0]
        #print line.partition('"')[-1].rpartition('"')[0]
        #print line.split()[0].split('[')[1].split(']')[0]
        hindi2eng[line.partition('[')[-1].rpartition(']')[0]] = line.partition('"')[-1].rpartition('"')[0]

with open("Data/UW_Hindi_Dict_20131003/hindi_function_word_dictionary.txt",encoding="utf8") as f:
    for line in f:
        #print line.partition('[')[-1].rpartition(']')[0]
        #print line.partition('"')[-1].rpartition('"')[0]
        #print line.split()[0].split('[')[1].split(']')[0]
        hindi2eng[line.partition('[')[-1].rpartition(']')[0]] = line.partition('"')[-1].rpartition('"')[0]

translate = {}

for element in transliterate:
    if (transliterate[element] in hindi2eng):
        translate[element] = hindi2eng[transliterate[element]]

print(len(translate))

translate_file = open("dictionary.pickle","wb")
pickle.dump(translate, translate_file)
translate_file.close()
# Out:
# 7036

# %%
import pandas as pd

object = pd.read_pickle("dictionary.pickle")

# %%
object
# Out:
# {'khushboo': 'scent(icl>fragrance)',
#  'khushbuu': 'scent(icl>fragrance)',
#  'tera': 'xiii(icl>number)',
#  'badan': 'body(icl>shape)',
#  'mera': '',
#  'meraa': '',
#  'meraaa': '',
#  'hawaa': 'current of air',
#  'hawa': 'current of air',
#  'havaa': 'current of air',
#  'ke': 'K',
#  'kaee': 'K',
#  'koee': 'K',
#  'khe': 'K',
#  'que': 'K',
#  'nasha': 'intoxication',
#  'sama': 'similar(aoj>thing)',
#  'samaan': 'undisputed(icl>equal)',
#  'samay': 'tide',
#  'bhi': '',
#  'bas': 'omnibus',
#  'jaise': 'for exmaple',
#  'ruup': 'version(icl>form)',
#  'ye': '',
#  'yye': '',
#  'yei': '',
#  'yey': '',
#  'baal': 'wool(icl>hair)',
#  'bal': 'wool(icl>hair)',
#  'hai': 'have(icl>be)',
#  'haan': 'yea',
#  'huye': 'in the very act of(icl>while doing)',
#  'tu': '',
#  'to': 'then',
#  'jo': '',
#  'paas': 'adjacent(aoj>thing)',
#  'pass': 'adjacent(aoj>thing)',
#  'pas': 'near(icl>close)',
#  'pyaas': 'thirstiness',
#  'paasa': 'dice',
#  'mujhe': '',
#  'muze': '',
#  'mujeh': '',
#  'mujhey': '',
#  'muzhe': '',
#  'muhjhe': '',
#  'mujkhe': '',
#  'pyas': 'thirstiness',
#  'pyaasaa': 'yearner',
#  'ka': 'of',
#  'kya': '',
#  'kaa': 'of',
#  'kar': 'tax(icl>tax-tax-payment)',
#  'khat': 'of',
#  'kal': 'yesterday',
#  'kam': 'wanting',
#  'kab': 'cub',
#  'kaam': 'game(icl>activity)',
#  'kan': 'of',
#  'khai': 'trench',
#  'kai': 'umpteen',
#  'ahsaas': 'feeling(icl>emotion)',
#  'ehasaas': 'feeling(icl>emotion)',
#  'ehsas': 'feeling(icl>emotion)',
#  'ahsas': 'feeling(icl>emotion)',
#  'yehasaas': 'feeling(icl>emotion)',
#  'ehasas': 'feeling(icl>emotion)',
#  'chaand': 'moon(icl>heavenly body)',
#  'chand': 'moon(icl>heavenly body)',
#  'chanad': 'moon(icl>heavenly body)',
#  'chhaand': 'moon(icl>heavenly body)',
#  'ham': '',
#  'hum': '',
#  'hama': '',
#  'hmm': '',
#  'hame': '',
#  'hume': '',
#  'hm': '',
#  'humi': '',
#  'tumhaaraa': 'thine(icl>yours)',
#  'tumhaara': 'thine(icl>yours)',
#  'tum': '',
#  'tuma': '',
#  'thum': '',
#  'ho': 'lnk',
#  'huh': 'lnk',
#  'had': 'precinct',
#  'heh': 'lnk',
#  'hamare': 'us',
#  'humare': 'us',
#  'humaare': 'us',
#  'hamara': '',
#  'hamarey': 'us',
#  'humhare': 'us',
#  'mela': 'funfair(icl>fair)',
#  'len': 'lane(icl>line)',
#  'hamen': '',
#  'hamein': '',
#  'humein': '',
#  'humen': '',
#  'humeein': '',
#  'humey': '',
#  'hmein': '',
#  'hamey': '',
#  'hamain': '',
#  'tumhen': '',
#  'tumhein': '',
#  'tumhey': '',
#  'chaahe': '',
#  'pyaar': 'love(icl>thing)',
#  'pyar': 'love(icl>thing)',
#  'paar': 'par(scn>golf)',
#  'paayar': 'love(icl>thing)',
#  'par': '',
#  'payar': 'love(icl>thing)',
#  'pyaara': 'par(scn>golf)',
#  'piyaao': 'love(icl>thing)',
#  'pyara': 'adorable(aoj>person)',
#  'pyaasa': 'yearner',
#  'pyaa': 'love(icl>thing)',
#  'paaya': 'leg(icl>thing)',
#  'dil': 'ticker',
#  'dill': 'ticker',
#  'dhil': 'ticker',
#  'men': 'within(icl>period)',
#  'mein': 'within(icl>period)',
#  'meein': 'within(icl>period)',
#  'maein': 'within(icl>period)',
#  'menu': 'within(icl>period)',
#  'masti': 'merrymaking',
#  'mastii': 'merrymaking',
#  'pyaaraa': 'adorable(aoj>person)',
#  'dekhna': 'visualise',
#  'jab': '',
#  'jaba': '',
#  'see': 'see(icl>place)',
#  'rangeen': 'full-colour(icl>state)',
#  'rangin': 'full-colour(icl>state)',
#  'rangiin': 'full-colour(icl>state)',
#  'hi': 'only(icl>very)',
#  'hee': 'only(icl>very)',
#  'he': 'have(icl>be)',
#  'hue': 'in the very act of(icl>while doing)',
#  'labh': 'payoff',
#  'per': '',
#  'kabhi': 'ever(icl>past)',
#  'door': 'wide(icl>far)',
#  'dur': 'wide(icl>far)',
#  'duur': 'wide(icl>far)',
#  'durr': 'wide(icl>far)',
#  'daur': 'streak',
#  'duurr': 'wide(icl>far)',
#  'saagar': 'deep',
#  'sagar': 'deep',
#  'chor': 'sneak',
#  'haa': 'ha',
#  'hahn': 'yea',
#  'haaan': 'yea',
#  'or': 'direction(icl>path)',
#  'kshitij': 'skyline',
#  'jahaan': '',
#  'jahan': '',
#  'jahaann': '',
#  'jahhan': '',
#  'jehan': '',
#  'zehan': '',
#  'baadal': 'pall',
#  'ghor': 'gross',
#  'deep': 'deep(aoj>darkness)',
#  'koi': '',
#  'kay': 'K',
#  'kalpana': 'abstract(icl>concept)',
#  'jagat': 'wellhead',
#  'mora': 'peacock(icl>bird)',
#  'jeevan': 'world(icl>life)',
#  'jiivan': 'world(icl>life)',
#  'jiwan': 'world(icl>life)',
#  'jeewan': 'world(icl>life)',
#  'jivan': 'world(icl>life)',
#  'jeeven': 'world(icl>life)',
#  'jivana': 'world(icl>life)',
#  'jiiwan': 'world(icl>life)',
#  'jeeivan': 'world(icl>life)',
#  'jiivana': 'world(icl>life)',
#  'mukt': 'at large',
#  'gan': 'gun',
#  'mor': 'peacock(icl>bird)',
#  'moor': 'peacock(icl>bird)',
#  'sundar': 'swell(icl>nice)',
#  'sunder': 'comely',
#  'aasha': 'prospect(icl>hope)',
#  'asha': 'prospect(icl>hope)',
#  'ashaa': 'prospect(icl>hope)',
#  'aisaa': 'similar',
#  'nitya': 'routine(icl>regular)',
#  'sada': 'informal(icl>casual)',
#  'sadaa': 'informal(icl>casual)',
#  'sadha': 'austere(aoj>thing)',
#  'sadai': 'informal(icl>casual)',
#  'bahar': 'without(icl>manner)',
#  'bhari': 'high(aoj>pressure,icl>degree)',
#  'baahar': 'without(icl>manner)',
#  'kaala': 'Black(aoj>ethnic group)',
#  'kala': 'acquisition',
#  'kaalaa': 'Black(aoj>ethnic group)',
#  'koyal': 'cuckoo',
#  'koyala': 'coal',
#  'us': 'that',
#  'uss': 'that',
#  'use': '',
#  'usse': 'therefrom',
#  'raat': 'night',
#  'raath': 'night',
#  'raata': 'night',
#  'rat': 'night',
#  'rasta': 'street',
#  'bela': 'violin(icl>musical instrument)',
#  'belaa': 'violin(icl>musical instrument)',
#  'gora': 'white(icl>pale-skinned)',
#  'goraa': 'white(icl>pale-skinned)',
#  'gorii': 'fair(aoj>skin)',
#  'chandni': 'moonlit',
#  'chandini': 'moonlit',
#  'chaandhni': 'moonlit',
#  'chaadani': 'moonlit',
#  'pe': 'over(aoj>communication channel)',
#  'mujhako': '',
#  'muhjko': '',
#  'mujko': '',
#  'mujjhko': '',
#  'mujhuko': '',
#  'mujkho': '',
#  'nila': 'sapphire',
#  'neela': 'sapphire',
#  'niilaa': 'sapphire',
#  'neelaa': 'sapphire',
#  'niila': 'sapphire',
#  'nilaa': 'sapphire',
#  'niil': 'indigo',
#  'kamal': 'lotus(icl>flower)',
#  'jin': 'gin',
#  'gahara': 'deep(aoj>darkness)',
#  'gaharaa': 'deep(aoj>darkness)',
#  'gahraa': 'deep(aoj>darkness)',
#  'gahera': 'deep(aoj>darkness)',
#  'gehra': 'deep(aoj>darkness)',
#  'gehraa': 'deep(aoj>darkness)',
#  'raaz': 'secret(icl>secrets)',
#  'raj': 'secret(icl>secrets)',
#  'sur': 'air(icl>music)',
#  'mitha': 'unsoured',
#  'lay': 'air(icl>music)',
#  'mithi': 'sweet(aoj>insincere praise)',
#  'mitti': 'gutter',
#  'honth': 'lip(pos>musical instrument)',
#  'hooth': 'lip(pos>musical instrument)',
#  'hoont': 'lip(pos>musical instrument)',
#  'hoot': 'lip(pos>musical instrument)',
#  'kahin': 'somewhere or other(icl>phrase)',
#  'kaheen': 'somewhere or other(icl>phrase)',
#  'kahiin': 'somewhere or other(icl>phrase)',
#  'kahii': 'somewhere or other(icl>phrase)',
#  'kahina': 'somewhere or other(icl>phrase)',
#  'aanchal': 'skirt(icl>part)',
#  'aachal': 'skirt(icl>part)',
#  'anchal': 'skirt(icl>part)',
#  'aanchala': 'skirt(icl>part)',
#  'gulabi': 'rosy',
#  'gulabee': 'rosy',
#  'gulaabii': 'rosy',
#  'gulaabee': 'rosy',
#  'chaal': 'plant',
#  'chal': 'travelling',
#  'chaala': 'plant',
#  'ankh': 'optic',
#  'aakh': 'optic',
#  'jaaduu': 'trick(icl>magic)',
#  'jadoo': 'trick(icl>magic)',
#  'jaado': 'trick(icl>magic)',
#  'jadu': 'trick(icl>magic)',
#  'jaadoo': 'trick(icl>magic)',
#  'jadhoo': 'trick(icl>magic)',
#  'narm': 'squashy',
#  'yahan': 'hither',
#  'yahaan': 'hither',
#  'yahaa': 'hither',
#  'kadam': 'step(icl>footsteps)',
#  'laakhon': 'trillion',
#  'laakho': 'trillion',
#  'lakho': 'trillion',
#  'lakhon': 'trillion',
#  'magar': '',
#  'alag': 'separated',
#  'kitne': '',
#  'kitanii': '',
#  'kitani': '',
#  'zaraa': 'visit(icl>go)',
#  'kisey': '',
#  'kasia': '',
#  'ajeebsi': 'weird(icl>strange,aoj>sound)',
#  'ajeeb': 'weird(icl>strange,aoj>sound)',
#  'ajiib': 'weird(icl>strange,aoj>sound)',
#  'ajib': 'weird(icl>strange,aoj>sound)',
#  'si': 'see(icl>place)',
#  'sii': 'see(icl>place)',
#  'madhur': 'singing',
#  'geet': 'vocal',
#  'giit': 'vocal',
#  'milan': 'union(icl>marriage)',
#  'milna': 'abut(icl>touch(aoj>thing,obj>thing))',
#  'man': 'nous',
#  'taar': 'conducting wire(icl>metal conductor)',
#  'thaar': 'conducting wire(icl>metal conductor)',
#  'sapana': 'pious hopes',
#  'suhaana': 'rosy',
#  'suhana': 'rosy',
#  'suhaanaa': 'rosy',
#  'na': 'season(agt>human,equ>accustom,gol>circumstances,obj>human)',
#  'naa': 'season(agt>human,equ>accustom,gol>circumstances,obj>human)',
#  'hosh': 'consciousness(icl>sense)',
#  'behosh': 'unconscious(ant>conscious)',
#  'main': '',
#  'hoy': 'have(icl>be)',
#  'hooo': 'lnk',
#  'gaanv': 'rural area',
#  'gaanw': 'rural area',
#  'baabuu': 'baboo',
#  'baaboo': 'baboo',
#  'rang': 'flavour',
#  'ranga': 'flavour',
#  'baith': 'sit-down(icl>state)',
#  'bait': 'sit-down(icl>state)',
#  'yehan': 'hither',
#  'yahana': 'hither',
#  'meri': 'Mary',
#  'merii': 'Mary',
#  'meray': 'Mary',
#  'raani': 'queen',
#  'raanii': 'queen',
#  'rani': 'queen',
#  'tujhako': '',
#  'tujhko': '',
#  'tujkho': '',
#  'tujko': '',
#  'tujhiko': '',
#  'tuhjko': '',
#  'tuzako': '',
#  'aaj': 'today(icl>the present time)',
#  'aj': 'today(icl>the present time)',
#  'don': 'don',
#  'doo': 'two(mod<thing)',
#  'tumako': '',
#  'tumakoe': '',
#  'tummko': '',
#  'lachak': 'sway(icl>movement)',
#  'tujhe': '',
#  'tuze': '',
#  'tujhey': '',
#  'tuje': '',
#  'tujeh': '',
#  'tuhje': '',
#  'tujhhe': '',
#  'tuj': '',
#  'maa': 'old lady(icl>mother)',
#  'maan': 'value(icl>standard)',
#  'maaen': 'old lady(icl>mother)',
#  'maaja': 'old lady(icl>mother)',
#  'maam': 'old lady(icl>mother)',
#  'laal': 'scarlet',
#  'tho': 'then',
#  'taxi': 'then',
#  'paanii': 'sewer',
#  'pani': 'sewer',
#  'phaani': 'sewer',
#  'kaun': '',
#  'kahaan': '',
#  'khabar': 'dope',
#  'chehraa': 'visage',
#  'khafa': '',
#  'chhaa': '',
#  'khahan': '',
#  'khafaa': '',
#  'kahaam': '',
#  'duniyase': 'world(icl>life)',
#  'dhuniyaa': 'world(icl>life)',
#  'dhuniya': 'world(icl>life)',
#  'duniyan': 'world(icl>life)',
#  'dooniya': 'world(icl>life)',
#  'duniye': 'world(icl>life)',
#  'duniyaaa': 'world(icl>life)',
#  'dunya': 'world(icl>life)',
#  'kitanaa': '',
#  'kitna': '',
#  'kitana': '',
#  'kitnaa': '',
#  'akelaa': 'unaccompanied',
#  'kaisaa': 'how(icl>interrogative)',
#  'kaisa': 'how(icl>interrogative)',
#  'kiska': '',
#  'din': 'daytime(icl>day)',
#  'har': 'each',
#  'harr': 'each',
#  'her': 'each',
#  'subah': 'morning(icl>time)',
#  'subha': 'morning(icl>time)',
#  'subaah': 'morning(icl>time)',
#  'subaha': 'morning(icl>time)',
#  'subho': 'morning(icl>time)',
#  'ab': 'yet(icl>now)',
#  'pawan': 'air(icl>gas)',
#  'pavan': 'air(icl>gas)',
#  'pavana': 'air(icl>gas)',
#  'gagan': 'heaven(icl>sky)',
#  'salona': 'pretty(aoj>boy)',
#  'saawala': 'swarthy',
#  'saanvala': 'swarthy',
#  'saanwala': 'swarthy',
#  'ko': 'on(fld>date)',
#  'kaza': 'on(fld>date)',
#  'ishaara': 'wave(mod>hand)',
#  'ishaaraa': 'wave(mod>hand)',
#  'ishara': 'wave(mod>hand)',
#  'donon': '',
#  'sung': 'company(icl>society)',
#  'sangh': 'order(icl>guild)',
#  'sanng': 'company(icl>society)',
#  'sanga': 'company(icl>society)',
#  'saang': 'company(icl>society)',
#  'koyi': '',
#  'khou': '',
#  'samje': 'wit',
#  'jaan': "the apple of <somebody's> eye(icl>favourite thing)",
#  'is': 'this(aoj>time)',
#  'ise': '',
#  'ies': 'this(aoj>time)',
#  'ish': 'this(aoj>time)',
#  'fasana': 'get(agt>problem,equ>beat,obj>human)',
#  'ya': '',
#  'yaa': '',
#  'yaar': 'sport(icl>human)',
#  'yaad': 'recollection(icl>remembrance)',
#  'yeah': '',
#  'yaya': '',
#  'yah': '',
#  'yan': '',
#  'yaah': '',
#  'unako': '',
#  'unko': '',
#  'ek': 'ace(icl>digit)',
#  'baat': 'words',
#  'bat': 'words',
#  'baata': 'words',
#  'baath': 'words',
#  'baaat': 'words',
#  'nafarat': 'disdain(icl>hate)',
#  'naam': 'title(icl>name of a person)',
#  'nam': 'title(icl>name of a person)',
#  'naama': 'title(icl>name of a person)',
#  'hamko': '',
#  'hamako': '',
#  'sangdil': 'unsympathetic',
#  'sangadil': 'unsympathetic',
#  'raah': 'road(icl>progress)',
#  'raaha': 'road(icl>progress)',
#  'e': '',
#  'behak': 'sheer off',
#  'bahak': 'sheer off',
#  'bahek': 'sheer off',
#  'behek': 'sheer off',
#  'jaam': 'snarl up',
#  'saamna': 'presence(icl>front)',
#  'saamana': 'presence(icl>front)',
#  'saamanaa': 'presence(icl>front)',
#  'samana': 'presence(icl>front)',
#  'shaam': 'fall(equ>nightfall)',
#  'sham': 'fall(equ>nightfall)',
#  'shama': 'fall(equ>nightfall)',
#  'shamo': 'fall(equ>nightfall)',
#  'nahin': 'other than(icl>not)',
#  'nahiin': 'other than(icl>not)',
#  'nahee': 'other than(icl>not)',
#  'nahie': 'other than(icl>not)',
#  'nahii': 'other than(icl>not)',
#  'nahien': 'other than(icl>not)',
#  'den': 'gift(icl>ability)',
#  'maar': 'swing(icl>action)',
#  'vo': '',
#  'wo': '',
#  'who': '',
#  'sooraj': 'sun(iof>star)',
#  'suraj': 'sun(iof>star)',
#  'suuraj': 'sun(iof>star)',
#  'kuchh': '',
#  'kuch': '',
#  'kucch': '',
#  'kuchi': '',
#  'aandhi': 'windstorm',
#  'aayi': 'I',
#  'aah': 'groan',
#  'mushkil': 'sod',
#  'mushakil': 'sod',
#  'phir': '',
#  'fir': '',
#  'fhir': '',
#  'dard': 'aching',
#  'bandhan': 'tying',
#  'patthar': 'stone(icl>piece of rock)',
#  'pathar': 'address(icl>geographic point)',
#  'pathhar': 'stone(icl>piece of rock)',
#  'paththar': 'stone(icl>piece of rock)',
#  'pather': 'stone(icl>piece of rock)',
#  'do': 'two(mod<thing)',
#  'patte': 'leaf(icl>amount)',
#  'mausam': 'weather(scn>climate)',
#  'mosam': 'weather(scn>climate)',
#  'mousam': 'weather(scn>climate)',
#  'mausama': 'weather(scn>climate)',
#  'mausum': 'weather(scn>climate)',
#  'safar': 'march(icl>distance)',
#  'usey': '',
#  'uuse': '',
#  'ussey': '',
#  'raahii': 'passer-by(icl>human)',
#  'raahi': 'passer-by(icl>human)',
#  'raahee': 'passer-by(icl>human)',
#  'mud': 'pride(icl>vigor)',
#  'bole': 'lyric',
#  'bhoole': 'lyric',
#  'bhed': 'shade',
#  'apane': '',
#  'apne': '',
#  'appne': '',
#  'apanee': '',
#  'apney': '',
#  'aaya': 'ayah',
#  'aayaa': 'ayah',
#  'ayaa': 'ayah',
#  'aaaa': 'ayah',
#  'kis': '',
#  'kisi': '',
#  'kiss': '',
#  'kaise': 'how(icl>manner)',
#  'kise': '',
#  'kaisi': '',
#  'desh': 'state',
#  'nirasha': 'despondence',
#  'niraasha': 'despondence',
#  'niraashaa': 'despondence',
#  'kora': 'clean(aoj>thing,equ>pure,icl>quality)',
#  'kyon': '',
#  'kyoon': '',
#  'kyoo': '',
#  'khushi': 'merriment(icl>feeling)',
#  'kushi': 'merriment(icl>feeling)',
#  'deewana': 'gaga',
#  'divaanaa': 'mad keen(icl>state)',
#  'divaana': 'mad keen(icl>state)',
#  'deewaana': 'gaga',
#  'deevaana': 'gaga',
#  'diwana': 'gaga',
#  'diivaanaa': 'gaga',
#  'diwaanaa': 'gaga',
#  'diivaana': 'gaga',
#  'deevaanaa': 'gaga',
#  'dewaana': 'gaga',
#  'deewaanaa': 'gaga',
#  'diwaana': 'mad keen(icl>state)',
#  'deewwaana': 'gaga',
#  'dewanna': 'gaga',
#  'divana': 'gaga',
#  'der': 'late(icl>late)',
#  'dher': 'late(icl>late)',
#  'zamana': 'jellify',
#  'zamaanaa': 'jellify',
#  'jamaana': 'jellify',
#  'shukar': 'Vesper',
#  'shukr': 'Vesper',
#  'shukra': 'Vesper',
#  'shukrr': 'Vesper',
#  'samajh': 'wit',
#  'samaj': 'world(icl>human society)',
#  'samjh': 'wit',
#  'khwaab': 'fantasy(icl>dream)',
#  'khvaab': 'fantasy(icl>dream)',
#  'khawab': 'fantasy(icl>dream)',
#  'kwaab': 'fantasy(icl>dream)',
#  'bin': 'BIN(equ>bank identification number)',
#  'saja': 'sentence(scn>criminal law)',
#  'khud': '',
#  'shaadi': 'marriage(icl>-wedding)',
#  'saare': 'around(icl>round)',
#  'saara': 'nub',
#  'pal': 'split second(icl>very short time)',
#  'khel': 'acrobatic stunt',
#  'aye': 'I',
#  'aayee': 'I',
#  'mahaka': 'nose(icl>smell)',
#  'aabaad': 'settled',
#  'abaad': 'settled',
#  'aabad': 'settled',
#  'bhuul': 'trip(icl>mistake)',
#  'bhul': 'trip(icl>mistake)',
#  'denaa': 'dole out',
#  'dienaa': 'dole out',
#  'dena': 'dole out',
#  'deeena': 'dole out',
#  'lenaa': 'have(icl>get(agt>person,obj>thing))',
#  'lena': 'have(icl>get(agt>person,obj>thing))',
#  'lenga': 'have(icl>get(agt>person,obj>thing))',
#  'mol': 'mole(icl>unit)',
#  'itni': 'so many(icl>certain number)',
#  'ithni': 'so many(icl>certain number)',
#  'itanii': 'so many(icl>certain number)',
#  'itanai': 'so many(icl>certain number)',
#  'bus': 'omnibus',
#  'baas': 'omnibus',
#  'saaya': 'spectre',
#  'saayaa': 'spectre',
#  'saya': 'spectre',
#  'saiya': 'spectre',
#  'parchhai': 'shadow(icl>atmosphere)',
#  'parchhaai': 'shadow(icl>atmosphere)',
#  'parchhaaii': 'shadow(icl>atmosphere)',
#  'parachhaai': 'shadow(icl>atmosphere)',
#  'parchhaayi': 'shadow(icl>atmosphere)',
#  'parchai': 'shadow(icl>atmosphere)',
#  'parchhayi': 'shadow(icl>atmosphere)',
#  'parchayi': 'shadow(icl>atmosphere)',
#  'baar': 'times',
#  'bar': 'times',
#  'baad': 'after(icl>how)',
#  'barr': 'times',
#  'zor': 'stress(icl>emphasis)',
#  'halka': 'subdued(mod>sound)',
#  'halkaa': 'subdued(mod>sound)',
#  'halakaa': 'soft(icl>light)',
#  'hua': 'lnk',
#  'huaa': 'lnk',
#  'huva': 'lnk',
#  'huya': 'lnk',
#  'saans': 'puff(icl>breath)',
#  'saas': 'mother-in-law(icl>human)',
#  'saaans': 'wind',
#  'uljha': 'entangled',
#  'uljaa': 'entangled',
#  'ulazaa': 'entangled',
#  'ulajhaa': 'entangled',
#  'sargoshi': 'whispering',
#  'saragoshi': 'whispering',
#  'behoshii': 'unconsciousness',
#  'behoshi': 'unconsciousness',
#  'behoshee': 'unconsciousness',
#  'jiina': 'survive(icl>live)',
#  'jinaa': 'survive(icl>live)',
#  'jeenaa': 'survive(icl>live)',
#  'jeena': 'survive(icl>live)',
#  'jina': 'survive(icl>live)',
#  'jiinaa': 'survive(icl>live)',
#  'junuun': 'mania',
#  'junun': 'mania',
#  'marna': 'snuff it(icl>die)',
#  'marrna': 'snuff it(icl>die)',
#  'marana': 'top(obj>ball)',
#  'maranaa': 'snuff it(icl>die)',
#  'marnaa': 'snuff it(icl>die)',
#  'maut': 'end(icl>infancy-youth-old age)',
#  'mout': 'end(icl>infancy-youth-old age)',
#  'god': 'go(icl>drug)',
#  'godi': 'pier',
#  'godh': 'lap(pof>legs)',
#  'bijali': 'bolt',
#  'bijli': 'bolt',
#  'bijalee': 'bolt',
#  'bijlee': 'bolt',
#  'bijalii': 'bolt',
#  'bijlii': 'bolt',
#  'aap': '',
#  'app': '',
#  'ap': '',
#  'yeh': '',
#  'yaha': 'hither',
#  'asar': 'leavening(icl>leaven)',
#  'asara': 'reliance(icl>shelter)',
#  'aasar': 'leavening(icl>leaven)',
#  'teer': 'bolt(icl>arrow)',
#  'tiir': 'bolt(icl>arrow)',
#  'tir': 'bolt(icl>arrow)',
#  'tiira': 'bolt(icl>arrow)',
#  'tasviir': 'visual(icl>picture)',
#  'niind': 'slumber',
#  'needh': 'slumber',
#  'ati': 'severe(equ>very bad)',
#  'aaraam': 'alleviation(icl>relief)',
#  'araam': 'alleviation(icl>relief)',
#  'kisse': '',
#  'varana': '',
#  'varanaa': '',
#  'varnaa': '',
#  'warana': '',
#  'waranaa': '',
#  'ghaayal': 'maimed',
#  'ghayal': 'maimed',
#  'gayal': 'maimed',
#  'karr': 'tax(icl>tax-tax-payment)',
#  'agni': 'flame',
#  'samne': 'opposite(icl>front)',
#  'saamane': 'opposite(icl>front)',
#  'sammne': 'opposite(icl>front)',
#  'jawan': 'big',
#  'javaana': 'big',
#  'sarhey': 'around(icl>round)',
#  'saaare': 'around(icl>round)',
#  'sare': 'around(icl>round)',
#  'khul': 'gross',
#  'kabh': 'cub',
#  'arey': 'dear',
#  'are': 'dear',
#  'arree': 'dear',
#  'haath': 'tool(pof>body)',
#  'tak': '',
#  'taka': '',
#  'aag': 'inferno',
#  'waqt': 'time(icl>period)',
#  'aage': 'ahead(icl>how,equ>forward)',
#  'aaghe': 'ahead(icl>how,equ>forward)',
#  'age': 'world(icl>period)',
#  'aapako': '',
#  'appko': '',
#  'aapko': '',
#  'apako': '',
#  'jisse': '',
#  'mil': 'mill(icl>factory)',
#  'usaki': 'hers(icl>woman)',
#  'uski': 'hers(icl>woman)',
#  'usakii': 'hers(icl>woman)',
#  'uskii': 'hers(icl>woman)',
#  'usakee': 'hers(icl>woman)',
#  'karake': '',
#  'karke': '',
#  'badanaam': 'notorious',
#  'badnaam': 'notorious',
#  'badanaama': 'notorious',
#  'badnam': 'notorious',
#  'badanam': 'notorious',
#  'aapakaa': 'yours',
#  'aapka': 'yours',
#  'aapaka': 'yours',
#  'aapkaa': 'yours',
#  'apaka': 'yours',
#  'javaab': 'answer(icl>speech act)',
#  'jawab': 'answer(icl>speech act)',
#  'jawaab': 'answer(icl>speech act)',
#  'salaam': 'salaam',
#  'salaame': 'salaam',
#  'salaama': 'salaam',
#  'maukaa': 'throw(icl>chance)',
#  'mauka': 'throw(icl>chance)',
#  'muka': 'throw(icl>chance)',
#  'jaana': 'visit(icl>go)',
#  'jana': 'visit(icl>go)',
#  'jan': 'public(icl>facility)',
#  'jaal': 'water',
#  'jaanaa': 'visit(icl>go)',
#  'jaldi': 'speedily',
#  'itanaa': 'that(icl>manner)',
#  'itana': 'that(icl>manner)',
#  'itna': 'that(icl>manner)',
#  'itnaa': 'that(icl>manner)',
#  'itne': 'so much(icl>certain amount)',
#  'mat': 'sect',
#  'mata': 'mum(icl>mother)',
#  'matt': 'sect',
#  'bad': 'after(icl>how)',
#  'khubsoorat': 'merry(icl>beautiful)',
#  'khubsurat': 'merry(icl>beautiful)',
#  'chahey': '',
#  'chhahe': '',
#  'soch': 'thinking',
#  'sochlo': 'thinking',
#  'palak': 'eyelid',
#  'band': 'tier',
#  'itane': 'so much(icl>certain amount)',
#  'karib': 'close to',
#  'kariib': 'close to',
#  'kareeb': 'close to',
#  'umra': 'years(icl>age)',
#  'umrr': 'years(icl>age)',
#  'umre': 'years(icl>age)',
#  'honahaar': 'up-and-coming(icl>state)',
#  'honhaar': 'up-and-coming(icl>state)',
#  'pyaare': 'darling(aoj>human)',
#  'pyare': 'darling(aoj>human)',
#  'pyaere': 'dear(mod>person)',
#  'bachche': 'children(icl>kids)',
#  'bacche': 'children(icl>kids)',
#  'dukh': 'misery(icl>unhappiness)',
#  'taang': 'leg(icl>wooden leg)',
#  'sinaa': 'tailor',
#  'seena': 'tailor',
#  'seenaa': 'tailor',
#  'siinaa': 'tailor',
#  'raasataa': 'street',
#  'rastaa': 'track(icl>road)',
#  'sunasaan': 'private(aoj>place,equ>retired)',
#  'sunsan': 'private(aoj>place,equ>retired)',
#  'toofaan': 'storm(icl>just of mind)',
#  'tufaan': 'storm(icl>just of mind)',
#  'toofan': 'storm(icl>just of mind)',
#  'paon': 'foot(icl>ankle-ankle-heel)',
#  'paau': 'foot(icl>ankle-ankle-heel)',
#  'paaw': 'foot(icl>ankle-ankle-heel)',
#  'panv': 'foot(icl>ankle-ankle-heel)',
#  'majabuur': 'helpless',
#  'majabur': 'helpless',
#  'majboor': 'helpless',
#  'majbur': 'helpless',
#  'majhboor': 'helpless',
#  'rukh': 'posture(icl>attitude)',
#  'duhkh': 'unhappiness',
#  'apanaa': 'their',
#  'apnaa': 'their',
#  'apna': 'their',
#  'apana': 'their',
#  'appna': 'their',
#  'apnana': 'their',
#  'sab': 'sub(icl>sandwich)',
#  'sub': 'sub(icl>sandwich)',
#  'sabh': 'sub(icl>sandwich)',
#  'agar': '',
#  'aagar': '',
#  'aggar': '',
#  'barabaad': 'sunk',
#  'barbaad': 'sunk',
#  'barbad': 'sunk',
#  'barabad': 'out of pocket(icl>phrase)',
#  'barabaada': 'out of pocket(icl>phrase)',
#  'vatan': 'home(icl>hometown-homeland)',
#  'aazadi': 'liberty(icl>freedom)',
#  'laachaar': 'powerless',
#  'mukh': 'opening',
#  'modh': 'zigzag',
#  'dhokhebaaj': 'double(aoj>human)',
#  'tikhaa': 'virulent',
#  'tikha': 'virulent',
#  'tiikhaa': 'virulent',
#  'vahi': 'very(icl>particular)',
#  'vahii': 'very(icl>particular)',
#  'vahee': 'very(icl>particular)',
#  'haar': 'one in the eye(icl>defeat)',
#  'mann': 'nous',
#  'badhata': 'thriving',
#  'sukh': 'eudaimonia',
#  'dam': 'weight(icl>strength)',
#  'ant': 'finish(icl>time)',
#  'jisaka': 'whose(icl>person)',
#  'jiska': 'whose(icl>person)',
#  'jisakaa': 'whose(icl>person)',
#  'jiskaa': 'whose(icl>person)',
#  'jisska': 'whose(icl>person)',
#  'disha': 'line(icl>reasoning)',
#  'dishaa': 'line(icl>reasoning)',
#  'sangi': 'partner(icl>person)',
#  'pathik': 'passenger(icl>traveller)',
#  'tara': 'star(icl>heavenly body)',
#  'kitney': '',
#  'chalana': 'wield',
#  'chalanaa': 'run(icl>do(agt>thing))',
#  'chalna': 'run(icl>do(agt>thing))',
#  'chalnaa': 'run(icl>do(agt>thing))',
#  'humara': '',
#  'humaaraa': '',
#  'hamaaraa': '',
#  'humaara': '',
#  'kaheti': 'farm(equ>farm team)',
#  'motor': 'motor',
#  'motar': 'motor',
#  'pyari': 'darling(aoj>human)',
#  'pyaaree': 'darling(aoj>human)',
#  'pyaarii': 'darling(aoj>human)',
#  'pyaree': 'darling(aoj>human)',
#  'boli': 'tongue(icl>way of speaking)',
#  'chinta': 'solicitude',
#  'chintaa': 'solicitude',
#  'roti': 'cake',
#  'piche': 'aback',
#  'peechhe': 'aback',
#  'peeche': 'aback',
#  'piichhe': 'aback',
#  'peche': 'aback',
#  'peechee': 'aback',
#  'naukar': 'slavey',
#  'naak': 'snout',
#  'chuppi': 'taciturnity',
#  'danga': 'trouble(icl>disturbance)',
#  'haal': 'tyre(icl>metal band)',
#  'hal': 'tyre(icl>metal band)',
#  'haala': 'tyre(icl>metal band)',
#  'beeta': 'past(icl>earlier than the present time)',
#  'beetaa': 'past(icl>earlier than the present time)',
#  'biitaa': 'past(icl>earlier than the present time)',
#  'bachpan': 'childhood(icl>time)',
#  'bachchpan': 'childhood(icl>time)',
#  'anban': 'rupture',
#  'anaban': 'rupture',
#  'bail': 'ox',
#  'sar': 'sir(icl>title)',
#  'sarr': 'sir(icl>title)',
#  'sir': 'sir(icl>title)',
#  'sara': 'lock(icl>thing)',
#  'pher': 'wind(icl>single turn)',
#  'suniye': 'hello(icl>listen)',
#  'tarah': 'manner(icl>kind)',
#  'tarahu': 'manner(icl>kind)',
#  'bharosa': 'faith(icl>spirit)',
#  'bharosaa': 'faith(icl>spirit)',
#  'koun': '',
#  'pahalu': 'strand',
#  'pahloo': 'strand',
#  'pahelu': 'strand',
#  'pehalu': 'strand',
#  'pahaluu': 'strand',
#  'pehloo': 'strand',
#  'lekin': '',
#  'lekien': '',
#  'lekeen': '',
#  'rakhna': 'steady',
#  'rakhana': 'steady',
#  'rakna': 'steady',
#  'jaisa': 'such as(icl>such)',
#  'jaisaa': 'such as(icl>such)',
#  'waise': 'incidentally',
#  'vaise': 'incidentally',
#  'shuruu': 'early(aoj>action)',
#  'kahani': 'yarn(icl>story)',
#  'kahaani': 'yarn(icl>story)',
#  'kahaanee': 'yarn(icl>story)',
#  'kahaanii': 'yarn(icl>story)',
#  'kahaane': 'yarn(icl>story)',
#  'gaon': 'rural area',
#  'gaav': 'rural area',
#  'gaaon': 'rural area',
#  'gaaoo': 'rural area',
#  'gaau': 'rural area',
#  'chota': 'younger',
#  'chhota': 'younger',
#  'chhotaa': 'younger',
#  'chohta': 'younger',
#  'choota': 'younger',
#  'sa': 'do(scn>music)',
#  'saa': 'do(scn>music)',
#  'sam': 'similar(aoj>thing)',
#  'saal': 'year',
#  'sau': 'hundred(icl>number)',
#  'kisee': '',
#  'kissi': '',
#  'kiske': '',
#  'kisie': '',
#  'sivaa': 'else(icl>manner)',
#  'chaah': 'longing',
#  'puravaiyaa': 'east(aoj>wind)',
#  'purvaiya': 'east(aoj>wind)',
#  'purawaiya': 'east(aoj>wind)',
#  'puravaiya': 'east(aoj>wind)',
#  'chandan': 'true sandalwood(icl>tree)',
#  'mahak': 'nose(icl>smell)',
#  'mahek': 'nose(icl>smell)',
#  'mehak': 'nose(icl>smell)',
#  'mehek': 'nose(icl>smell)',
#  'dulhan': 'bride',
#  'usako': '',
#  'ussko': '',
#  'jaha': '',
#  'shor': 'shout(icl>voice-feeling)',
#  'so': 'hundred(icl>number)',
#  'aansoo': 'teardrop',
#  'aansu': 'teardrop',
#  'aansuu': 'teardrop',
#  'aanso': 'teardrop',
#  'aasoo': 'teardrop',
#  'ansu': 'teardrop',
#  'aasu': 'teardrop',
#  'ansoo': 'teardrop',
#  'bina': 'unaccompanied',
#  'binaa': 'unaccompanied',
#  'beshumaar': 'incalculable',
#  'sandhya': 'evening',
#  'sandhyaa': 'evening',
#  'chanda': 'subscription',
#  'chandaa': 'collection(icl>donation)',
#  'chanhda': 'subscription',
#  'hogii': 'hoagy(icl>sandwich)',
#  'hoongi': 'hoagy(icl>sandwich)',
#  'hogee': 'hoagy(icl>sandwich)',
#  'muskil': 'sod',
#  'mushkila': 'sod',
#  'muskhil': 'sod',
#  'mane': 'Manet(iof>person)',
#  'sal': 'year',
#  'aasmaan': 'sky(icl>heaven)',
#  'aasamaan': 'sky(icl>heaven)',
#  ...}
